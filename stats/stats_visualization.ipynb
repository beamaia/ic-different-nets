# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
stats = pd.read_csv("stats.csv", sep=",")

# %%
stats = stats.drop(["Unnamed: 0", "Version"], axis=1)

# %%
df_dates = stats["Date"].str.split("-")
dates = []

for string in df_dates:
    dates.append(int(string[0]))

# %%
stats.insert(loc=0, column='Day', value=dates)

# %%
stats = stats.drop(["Date"], axis=1)

# %%
stats_train80 = stats.loc[(stats["Day"] > 18)] 
resnet_train70 = stats.loc[(stats["Day"] < 18)]

# %%
resnet_train80 = stats_train80.loc[(stats_train80["Model"] == "resnet50")] 
inception = stats_train80.loc[(stats_train80["Model"] == "inceptionv3")] 
mobilenet = stats_train80.loc[(stats_train80["Model"] == "mobilenetv2")]

# %%
summary_resnet_70_set1 = resnet_train70.loc[(resnet_train70["Set"] == 1)].describe()
summary_resnet_80_set1 = resnet_train80.loc[(resnet_train80["Set"] == 1)].describe()
summary_inception_set1 = inception.loc[(inception["Set"] == 1)].describe()
summary_mobilenet_set1 = mobilenet.loc[(mobilenet["Set"] == 1)].describe()

# %%
summary_resnet_70_set2 = resnet_train70.loc[(resnet_train70["Set"] == 2)].describe()
summary_resnet_80_set2 = resnet_train80.loc[(resnet_train80["Set"] == 2)].describe()
summary_inception_set2 = inception.loc[(inception["Set"] == 2)].describe()
summary_mobilenet_set2 = mobilenet.loc[(mobilenet["Set"] == 2)].describe()

# %%
summary_resnet_70_set3 = resnet_train70.loc[(resnet_train70["Set"] == 3)].describe()
summary_resnet_80_set3 = resnet_train80.loc[(resnet_train80["Set"] == 3)].describe()
summary_inception_set3 = inception.loc[(inception["Set"] == 3)].describe()
summary_mobilenet_set3 = mobilenet.loc[(mobilenet["Set"] == 3)].describe()

# %%
mean_resnet_80_set1 = summary_resnet_80_set1.iloc[1]["Accuracy"]
mean_resnet_70_set1 = summary_resnet_70_set1.iloc[1]["Accuracy"]

min_resnet_80_set1 = summary_resnet_80_set1.iloc[3]["Accuracy"]
min_resnet_70_set1 = summary_resnet_70_set1.iloc[3]["Accuracy"]

max_resnet_80_set1 = summary_resnet_80_set1.iloc[7]["Accuracy"]
max_resnet_70_set1 = summary_resnet_70_set1.iloc[7]["Accuracy"]

# %%
mean_resnet_80_set2 = summary_resnet_80_set2.iloc[1]["Accuracy"]
mean_resnet_70_set2 = summary_resnet_70_set2.iloc[1]["Accuracy"]

min_resnet_80_set2 = summary_resnet_80_set2.iloc[3]["Accuracy"]
min_resnet_70_set2 = summary_resnet_70_set2.iloc[3]["Accuracy"]

max_resnet_80_set2 = summary_resnet_80_set2.iloc[7]["Accuracy"]
max_resnet_70_set2 = summary_resnet_70_set2.iloc[7]["Accuracy"]

# %%
mean_resnet_80_set3 = summary_resnet_80_set3.iloc[1]["Accuracy"]
mean_resnet_70_set3 = summary_resnet_70_set3.iloc[1]["Accuracy"]

min_resnet_80_set3 = summary_resnet_80_set3.iloc[3]["Accuracy"]
min_resnet_70_set3 = summary_resnet_70_set3.iloc[3]["Accuracy"]

max_resnet_80_set3 = summary_resnet_80_set3.iloc[7]["Accuracy"]
max_resnet_70_set3 = summary_resnet_70_set3.iloc[7]["Accuracy"]

# %%
mean_inception_set1 = summary_inception_set1.iloc[1]["Accuracy"]
mean_inception_set2 = summary_inception_set2.iloc[1]["Accuracy"]
mean_inception_set3 = summary_inception_set3.iloc[1]["Accuracy"]

min_inception_set1 = summary_inception_set1.iloc[3]["Accuracy"]
min_inception_set2 = summary_inception_set2.iloc[3]["Accuracy"]
min_inception_set3 = summary_inception_set3.iloc[3]["Accuracy"]

max_inception_set1 = summary_inception_set1.iloc[7]["Accuracy"]
max_inception_set2 = summary_inception_set2.iloc[7]["Accuracy"]
max_inception_set3 = summary_inception_set3.iloc[7]["Accuracy"]

# %%
mean_mobilenet_set1 = summary_mobilenet_set1.iloc[1]["Accuracy"]
mean_mobilenet_set2 = summary_mobilenet_set2.iloc[1]["Accuracy"]
mean_mobilenet_set3 = summary_mobilenet_set3.iloc[1]["Accuracy"]

min_mobilenet_set1 = summary_mobilenet_set1.iloc[3]["Accuracy"]
min_mobilenet_set2 = summary_mobilenet_set2.iloc[3]["Accuracy"]
min_mobilenet_set3 = summary_mobilenet_set3.iloc[3]["Accuracy"]

max_mobilenet_set1 = summary_mobilenet_set1.iloc[7]["Accuracy"]
max_mobilenet_set2 = summary_mobilenet_set2.iloc[7]["Accuracy"]
max_mobilenet_set3 = summary_mobilenet_set3.iloc[7]["Accuracy"]

# %%
resnet_80_set1 = [min_resnet_80_set1, mean_resnet_80_set1, max_resnet_80_set1]
resnet_70_set1 = [min_resnet_70_set1, mean_resnet_70_set1, max_resnet_70_set1]

# %%
resnet_80_set2 = [min_resnet_80_set2, mean_resnet_80_set2, max_resnet_80_set2]
resnet_70_set2 = [min_resnet_70_set2, mean_resnet_70_set2, max_resnet_70_set2]

# %%
resnet_80_set3 = [min_resnet_80_set3, mean_resnet_80_set3, max_resnet_80_set3]
resnet_70_set3 = [min_resnet_70_set3, mean_resnet_70_set3, max_resnet_70_set3]

# %%
inception_set1 = [min_inception_set1, mean_inception_set1, max_inception_set1]
inception_set2 = [min_inception_set2, mean_inception_set2, max_inception_set2]
inception_set3 = [min_inception_set3, mean_inception_set3, max_inception_set3]

# %%
mobilenet_set1 = [min_mobilenet_set1, mean_mobilenet_set1, max_mobilenet_set1]
mobilenet_set2 = [min_mobilenet_set2, mean_mobilenet_set2, max_mobilenet_set2]
mobilenet_set3 = [min_mobilenet_set3, mean_mobilenet_set3, max_mobilenet_set3]

# %%
def plot_min_mean_max(values, version=1, set_num = 1, strs=["resnet50", "mobilenet-v2", "inception-v3"], bar_num=3, extra=""):
    labels = ['Min', 'Mean', 'Max']
    x = np.arange(len(labels))  
    fig, ax = plt.subplots(figsize=(10, 5))
    path = "./imgs/"
   
    def subcategorybar(labels, values, x, strings, width=0.8):
        color=['springgreen', 'dodgerblue', 'mediumpurple']
#         color=['royalblue', 'limegreen', 'darkorange']

        n = len(values)
        rects = []
        for i in range(n):
            a = plt.bar(x - width/2. + i/float(n)*width, values[i], width=width/float(n), align="edge", 
                        label=strings[i], color=color[i])   
            rects.append(a)
        plt.xticks(x, labels)
    
        return rects
    
    rects = subcategorybar(labels, values, x, strs)
    
    
    if set_num == 1:
        set_string = "Set 1"
    elif set_num == 2:
        set_string = "Set 2"
    elif set_num == 3:
        set_string = "Both Sets"
        
    if len(extra) != 0:
        set_string += " - " + extra
        path += extra.lower() + "_"

    title = 'Min, Mean and Max Accuracy - ' + set_string
    ax.set_ylabel('Percentage (%)')
    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend(loc='upper right',  bbox_to_anchor=(1.20, 1))

    ax.set_ylim([0,100])

    def autolabel(rects):
        for bar in rect:
            height = bar.get_height().round(2)
            ax.annotate('{}'.format(height),
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 10),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')

    for rect in rects:
        autolabel(rect)

    fig.tight_layout()
#     plt.show()
    path += "min_mean_max_set" + str(set_num) + "_version_" + str(version) + ".png"    
    
    plt.savefig(path, format="png", transparent=False, edgecolor="white")

# %%
values=[resnet_70_set1, resnet_80_set1]
plot_min_mean_max(values=values, version=1, extra="Resnet", set_num = 1, strs=["70% train", "80% train"], bar_num=2)

# %%
values=[resnet_70_set2, resnet_80_set2]
plot_min_mean_max(values=values, version=2, extra="Resnet", set_num = 2, strs=["70% train", "80% train"], bar_num=2)

# %%
values=[resnet_70_set3, resnet_80_set3]
plot_min_mean_max(values=values, version=3, extra="Resnet", set_num = 3, strs=["70% train", "80% train"], bar_num=2)

# %%
values=[resnet_80_set1, mobilenet_set1, inception_set1]
plot_min_mean_max(values=values, version=1,set_num = 1)

# %%
values=[resnet_80_set2, mobilenet_set2, inception_set2]
plot_min_mean_max(values=values, version=2, set_num = 2)

# %%
values=[resnet_80_set3, mobilenet_set3, inception_set3]
plot_min_mean_max(values=values, version=3,set_num = 3)
